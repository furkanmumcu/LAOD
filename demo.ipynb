# %%
import laod
from PIL import Image
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
# load input image
image = Image.open('images/1.jpg')
plt.imshow(image)
plt.axis('off') # Optional: Hides the axes
plt.show()

# %%
result = laod.laod_gdino(image)
# Out:
# LLM response: Cats, sofa, remote control
# Detected cats with confidence 0.636 at location [345, 24, 639, 373]
# Detected sofa with confidence 0.64 at location [2, 1, 638, 478]
# Detected cats with confidence 0.679 at location [10, 53, 317, 474]
# Detected remote control with confidence 0.479 at location [40, 71, 176, 118]

# %%
plt.imshow(result)
plt.axis('off')
plt.show()
